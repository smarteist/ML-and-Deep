# %%
# This code assumes TensorFlow 2.x is used
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
# Out:
# 2023-12-16 14:30:53.241585: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-16 14:30:54.089402: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-16 14:30:54.092528: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-16 14:30:55.427596: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# 1. Generate Data
# Prepare sine wave data
x = np.linspace(0, 100, 10000)
y = np.sin(x)

# %%
x[7]
# Out:
# 0.07000700070007002

# %%
y[7]
# Out:
# 0.06994983089117608

# %%
# Function to create sequences
def create_sequences(data, seq_len):
    xs = []
    ys = []
    for i in range(len(data) - seq_len):
        xs.append(data[i:(i + seq_len)])
        ys.append(data[i + seq_len])
    return np.array(xs), np.array(ys)

# %%
seq_length = 5


X, y = create_sequences(y, seq_length)

# Reshape X for RNN input
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Split the data into training and testing
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
np.shape(X_train)
# Out:
# (7945, 5, 1)

# %%
# 2. Build the RNN model
model = Sequential([
    SimpleRNN(50, return_sequences=True, input_shape=(seq_length, 1)),
    SimpleRNN(50),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# 3. Train the Model
history = model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/5
# 224/224 [==============================] - 5s 15ms/step - loss: 0.0076 - val_loss: 1.3823e-04
# Epoch 2/5
# 224/224 [==============================] - 3s 14ms/step - loss: 7.1602e-05 - val_loss: 3.4384e-05
# Epoch 3/5
# 224/224 [==============================] - 3s 14ms/step - loss: 2.5489e-05 - val_loss: 1.3389e-05
# Epoch 4/5
# 224/224 [==============================] - 3s 14ms/step - loss: 1.3514e-05 - val_loss: 8.0856e-06
# Epoch 5/5
# 224/224 [==============================] - 3s 14ms/step - loss: 7.5683e-06 - val_loss: 6.9727e-06

# %%
# 4. Evaluate
# Predict on the test data
predicted = model.predict(X_test)

# Plot the results
plt.plot(y_test, label='True Value')
plt.plot(predicted, label='Predicted Value')
plt.legend()
plt.show()
# Out:
# 63/63 [==============================] - 0s 4ms/step
